# %% [markdown]
# <a href="https://colab.research.google.com/github/matthewreed2000/cse380-notebooks/blob/master/14_1_My_Final_Grade_Claim_for_W21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Final Grade Claim
# ## CSE 380 Discrete Mathematics II
# ### Winter 2021
#
# *Matthew Reed*

# %% [markdown]
# ![final-grade-claim-decision.png](data:image/png;base64,...)

# %% [markdown]
# ## Top Evidences

# %% [markdown]
# - [W09 Prove - Functional Function](https://colab.research.google.com/github/matthewreed2000/cse380-notebooks/blob/master/09_2_Ponder_and_Prove_Data_Compression.ipynb#scrollTo=nTzhSN3U5be0&line=3&uniqifier=1)
# - [W12 Prove - Understanding the Pigeonhole Principle](https://colab.research.google.com/github/matthewreed2000/cse380-notebooks/blob/master/12_2_Ponder_and_Prove_The_Pigeonhole_Principle.ipynb#scrollTo=hEpxxRrO_6N5)

# %% [markdown]
# ## Above and Beyond

# %% [markdown]
# - [W09 Prove - Reversing Huffman Trees](https://colab.research.google.com/github/matthewreed2000/cse380-notebooks/blob/master/09_2_Ponder_and_Prove_Data_Compression.ipynb#scrollTo=4tIEKUV_Fk5c)
#   - When my group finished implementing Huffman encoding for the differences between primes, we decided that we wanted to decode what we had encoded. (What's the point of compression if you can't decompress it?)
#
# - [W10 Prove - Graphing Graphs](https://colab.research.google.com/github/matthewreed2000/cse380-notebooks/blob/master/10_2_Ponder_and_Prove_Spanning_Trees.ipynb#scrollTo=iQFTWNgfaCFj&line=1&uniqifier=1)
#   - Rather than generating ladder graphs or large randomized graphs by hand, I wrote functions to do it for me.
#   - My group used displayed the graphs graphically. (This was before we discussed graphics libraries in class.)
#   - My group challenged themselves to write everything using functional programming (except for object-oriented graphics libraries)
#
# - [W11 DPC - Automating Word Graph Paths](https://colab.research.google.com/github/matthewreed2000/cse380-notebooks/blob/master/11_1_About_Paths_in_Word_Graphs.ipynb#scrollTo=rnLg1gizJNNC&line=8&uniqifier=1)
#   - Instead of connecting words by hand, I wrote a couple of functions that recursively checked what nodes were connected until it found the target word.
#
# - [W11 Prove - An Attempt](https://colab.research.google.com/github/matthewreed2000/cse380-notebooks/blob/master/11_2_Ponder_and_Prove_Verifying_Graph_Properties.ipynb#scrollTo=3-nYIdEUz4x5)
#   - When my group and I were still discussing optimization, I thought of Gödel Hashes and Cantor's Pairing Function. I attempted to implement these with the given graphs, but I was limited by NumPy's fixed integer size and could not complete the implementation.
#
# - [W12 CDL - Automating Autamata](https://colab.research.google.com/github/matthewreed2000/cse380-notebooks/blob/master/12_3_About_Deterministic_Finite_Automata.ipynb#scrollTo=u9sP9lFGIKRG&line=12&uniqifier=1)
#   - Instead of creating the graph descriptions by hand, I looked for patterns in the previous graph descriptions, then wrote a function to generate them.
